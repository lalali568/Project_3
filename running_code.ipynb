# %% [markdown]
# # 初始化路径和git

# %%
import os
os.chdir('/content/drive/MyDrive/P3/Project_3')
# !ls
# Out:
# config	data  dataset  main.py	models	README.md  running_code.ipynb  tester  trainers  utils

# %%
#!git clone https://github.com/lalali568/Project_3.git

# %%
# !git config --global user.email "colab@example.com"
# !git config --global user.name "colab"

# %%
#
from getpass import getpass
#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
token = getpass('Enter your GitHub Token: ')
repository = f"https://{token}@github.com/lalali568/Project_3.git"

# !git remote set-url origin {repository}
# !git push origin master

# %% [markdown]
# # 运行代码

# %%
#我想通过调取main.py运行代码
# !python main.py
# Out:
# {'model': 'D3R', 'seed': 1, 'device': 'cuda', 'dataset': 'SMD', 'SMD': {'lr': 0.0001, 'batch_size': 32, 'epochs': 10, 'patience': 3, 'train_data_path': 'data/SMD/SMD_train_data.npy', 'train_date_path': 'data/SMD/SMD_train_date.npy', 'test_data_path': 'data/SMD/SMD_test_data.npy', 'test_date_path': 'data/SMD/SMD_test_date.npy', 'test_label_path': 'data/SMD/SMD_test_label.npy', 'period': 1440, 'train_rate': 0.8, 'feature_num': 0, 'time_num': 0, 'window_size': 60, 'dropout': 0.6, 'time_steps': 100, 'beta_start': 0.0001, 'beta_end': 0.02, 't': 500, 'p': 1, 'd': 30, 'q': 0.01, 'model_dim': 512, 'ff_dim': 2048, 'atten_dim': 64, 'block_num': 2, 'head_num': 4}, 'SWAT': {'train_data_path': 'data/SWAT/SWAT_train_data.npy', 'train_date_path': 'data/SWAT/SWAT_train_date.npy'}, 'lr': 0.0001, 'batch_size': 32, 'epochs': 10, 'patience': 3, 'train_data_path': 'data/SMD/SMD_train_data.npy', 'train_date_path': 'data/SMD/SMD_train_date.npy', 'test_data_path': 'data/SMD/SMD_test_data.npy', 'test_date_pa
# ...

# %%
# !git add .
# !git commit -m "from colab"
# !git push origin master
