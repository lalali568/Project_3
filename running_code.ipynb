# %%
import os
os.chdir('/content/drive/MyDrive/P3/Project_3')
# !ls
# Out:
# config	data  dataset  main.py	models	README.md  running_code.ipynb  tester  trainers  utils

# %%
# !git clone https://github.com/lalali568/Project_3.git
# Out:
# Cloning into 'Project_3'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 55 (delta 8), reused 51 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (55/55), 29.99 MiB | 10.69 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# Updating files: 100% (38/38), done.
